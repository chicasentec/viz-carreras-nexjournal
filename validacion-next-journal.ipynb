# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from collections import namedtuple
from scipy import stats
import seaborn as sns
import geopandas as gpd
import matplotlib
import ipywidgets as widgets
from ipywidgets import interact
matplotlib.style.use("ggplot")
import folium
from folium.plugins import DualMap 
import mapas
from shapely.geometry import Polygon, MultiPolygon

# %%
df_evolucion_carreras = pd.read_csv('data/output/carreras_evolucion_genero.csv',delimiter=',')
df_evolucion_grupos_carreras = pd.read_csv('data/output/grupo_carreras_evolucion_genero.csv',delimiter=',')

# %%
df_evolucion_grupos_carreras.head(10)
# Out:
#    anio carrera_grupo                              carrera_nombre  \
# 0  2010       Abogado                                    Abogacia
# 1  2010       Abogado                                Criminologia
# 2  2010       Abogado                Derecho y Ciencias Juridicas
# 3  2010       Abogado                                   Filosofia
# 4  2010  Arquitectura                    Arquitectura y Urbanismo
# 5  2010  Arquitectura  Ciencias del Ambiente y Recursos Naturales
# 6  2010  Arquitectura                              Construcciones
# 7  2010  Arquitectura                        Diseño de Interiores
# 8  2010  Arquitectura                            Ingenieria Naval
# 9  2010  Arquitectura                             Ingenieria Vial
#
#    estudiantes_total  estudiantes_varones  estudiantes_mujeres  \
# 0           197845.0              70408.0              91945.0
# 1              285.0                171.0                114.0
# 2            14546.0               6301.0               8245.0
# 3               34.0                 18.0                 16.0
# 4            55371.0              21080.0              18887.0
# 5               36.0                 16.0                 20.0
# 6              164.0                134.0                 30.0
# 7             2094.0                266.0               1828.0
# 8              182.0                133.0                 15.0
# 9               62.0                 58.0                  4.0
#
#    nuevos_inscriptos_total  nuevos_inscriptos_varones  \
# 0                  41860.0                    16500.0
# 1                     42.0                       15.0
# 2                   4096.0                     1774.0
# 3                     26.0                       14.0
# 4                   9273.0                     3429.0
# 5                     27.0                       13.0
# 6                     67.0                       56.0
# 7                    574.0                       76.0
# 8                     62.0                       33.0
# 9                     48.0                       45.0
#
#    nuevos_inscriptos_mujeres  egresados_total  egresados_varones  \
# 0                    19749.0          10773.0             3382.0
# 1                       27.0             14.0                9.0
# 2                     2322.0           1697.0              351.0
# 3                       12.0              1.0                1.0
# 4                     3263.0           2535.0              890.0
# 5                       14.0              0.0                0.0
# 6                       11.0              4.0                2.0
# 7                      498.0            104.0               10.0
# 8                        6.0             10.0               10.0
# 9                        3.0              2.0                2.0
#
#    egresados_mujeres  estudiantes_mujeres_pct  inscripciones_mujeres_pct
# 0             4612.0                 0.464732                   0.471787
# 1                5.0                 0.400000                   0.642857
# 2              356.0                 0.566822                   0.566895
# 3                0.0                 0.470588                   0.461538
# 4              993.0                 0.341099                   0.351882
# 5                0.0                 0.555556                   0.518519
# 6                2.0                 0.182927                   0.164179
# 7               94.0                 0.872970                   0.867596
# 8                0.0                 0.082418                   0.096774
# 9                0.0                 0.064516                   0.062500

# %%
grupo = 'Economicas'
df_grupo_carrera = df_evolucion_grupos_carreras[df_evolucion_grupos_carreras.carrera_grupo == grupo][[
        "anio", "estudiantes_mujeres_pct", 'carrera_nombre', 'carrera_grupo'
    ]]
df_grupo_carrera.pivot_table(index='anio', columns='carrera_nombre', values='estudiantes_mujeres_pct').plot(
figsize=(20,20))

# %%
#chequear los datos de UBA porque habian incosistencias en 2010. Tabla de los numeros absolutos de la universidad.
